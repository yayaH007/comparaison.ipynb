# %%
from observation_cours_funct import plot_cours ,plot_variation ,plot_cours_mean ,histogramePrice
name="Total"

# %% [markdown]
# Cours Courbe

# %%
plot_cours(name)
# Out:
# alt.Chart(...)

# %% [markdown]
# Variation courbe

# %%
plot_variation(name)
# Out:
# alt.Chart(...)

# %%
plot_cours_mean(name,"Month")
# Out:
# alt.LayerChart(...)

# %%
plot_cours_mean(name,"Trimester")
# Out:
# alt.LayerChart(...)

# %%
histogramePrice(name)
# Out:
# alt.Chart(...)
