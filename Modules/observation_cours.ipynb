# %%
from observation_cours_fun import plot_cours ,plot_variation ,plot_cours_mean ,histogramePriceAll ,histogramePriceMonth,histogramePriceTrimestre,histogramePriceYear , plot_two
name="Total"

# %% [markdown]
# Cours Courbe

# %%
plot_cours(name)
# Out:
# alt.Chart(...)

# %%
plot_cours("CAC40")
# Out:
# alt.Chart(...)

# %% [markdown]
# Variation courbe

# %%
plot_variation(name)
# Out:
# alt.Chart(...)

# %%
plot_cours_mean(name,"Week")
# Out:
# alt.LayerChart(...)

# %%
plot_cours_mean(name,"Trimester")
# Out:
# alt.LayerChart(...)

# %%
plot_cours_mean(name,"Month")
# Out:
# alt.LayerChart(...)

# %%
histogramePriceAll(name)
# Out:
# alt.Chart(...)

# %%
histogramePriceMonth(name)
# Out:
# alt.Chart(...)

# %%
histogramePriceTrimestre(name)
# Out:
# alt.Chart(...)

# %%
histogramePriceYear(name)
# Out:
# alt.Chart(...)

# %%
plot_cours("Airbnb")
# Out:
# alt.Chart(...)

# %%
plot_two("Dow_Jones","CAC40")
# Out:
# alt.LayerChart(...)
